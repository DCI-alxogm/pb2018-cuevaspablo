# %%
#Programa creado por José Pablo 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
#(d2o/dt2)+(w2)*(o)=0
#(do/dt)=v
#(d2o/dt2)=dv/dt
#(dv/dt)=-(w2)o=f1
#(do/dt)=v=f2
#v(ti+1)=v(ti)+h*f1
#o(ti+1)=o(ti)+h*f2
e=100000
T=1
pi=3.14159265358979323846
h=0.00001
w=2*pi/T
o=np.linspace(180,180,e)
v=np.linspace(0,10,e)
t=np.linspace(0,10,e)
def fx(w,o):
    z=(-(pow(w,2)))*o
    return z
z=fx(w,o)
#

# %%
for i in range (e-1):
    v[i+1]=v[i]+(h*(fx(w,o[i])))
    o[i+1]=o[i]+(h*v[i])

# %%
plt.plot(v,o)

# %%
plt.plot(t,v)

# %%
plt.plot(t,o)
