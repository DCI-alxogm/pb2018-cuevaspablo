# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
#(d2o/dt2)+(w2)*(o)=0
#(do/dt)=v
#(d2o/dt2)=dv/dt
#(dv/dt)=-(w2)o=f1
#(do/dt)=v=f2
#v(ti+1)=v(ti)+h*f1
#o(ti+1)=o(ti)+h*f2

# %%
def fx((-w**2)*(o)):
return 0
def fx2()

# %%
for i in range ()
